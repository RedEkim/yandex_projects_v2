# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span><ul class="toc-item"><li><span><a href="#Оптимизация-данных" data-toc-modified-id="Оптимизация-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Оптимизация данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски-в-столбцах-days_employed-и-total_income" data-toc-modified-id="Пропуски-в-столбцах-days_employed-и-total_income-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропуски в столбцах days_employed и total_income</a></span></li><li><span><a href="#Аномалии-в-данных" data-toc-modified-id="Аномалии-в-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Аномалии в данных</a></span></li><li><span><a href="#Замена-типа-данных-в-столбце-total_income" data-toc-modified-id="Замена-типа-данных-в-столбце-total_income-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Замена типа данных в столбце total_income</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Создание-двух-новых-датафреймов" data-toc-modified-id="Создание-двух-новых-датафреймов-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Создание двух новых датафреймов</a></span></li><li><span><a href="#Функция-категории-дохода" data-toc-modified-id="Функция-категории-дохода-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция категории дохода</a></span></li><li><span><a href="#Функция-категоризации-целей-кредита" data-toc-modified-id="Функция-категоризации-целей-кредита-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция категоризации целей кредита</a></span></li></ul></li><li><span><a href="#Ответы-на-вопросы" data-toc-modified-id="Ответы-на-вопросы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ответы на вопросы</a></span><ul class="toc-item"><li><span><a href="#Зависимость-между-количеством-детей-и-возвратом-кредита-в-срок?" data-toc-modified-id="Зависимость-между-количеством-детей-и-возвратом-кредита-в-срок?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Зависимость между количеством детей и возвратом кредита в срок?</a></span></li><li><span><a href="#Зависимость-между-семейным-положением-и-возвратом-кредита-в-срок?" data-toc-modified-id="Зависимость-между-семейным-положением-и-возвратом-кредита-в-срок?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Зависимость между семейным положением и возвратом кредита в срок?</a></span></li><li><span><a href="#Зависимость-между-уровнем-дохода-и-возвратом-кредита-в-срок?" data-toc-modified-id="Зависимость-между-уровнем-дохода-и-возвратом-кредита-в-срок?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Зависимость между уровнем дохода и возвратом кредита в срок?</a></span></li><li><span><a href="#Как-разные-цели-кредита-влияют-на-его-возврат-в-срок?" data-toc-modified-id="Как-разные-цели-кредита-влияют-на-его-возврат-в-срок?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Как разные цели кредита влияют на его возврат в срок?</a></span></li></ul></li><li><span><a href="#Дополнительные-вопросы-и-ответы-на-них" data-toc-modified-id="Дополнительные-вопросы-и-ответы-на-них-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Дополнительные вопросы и ответы на них</a></span><ul class="toc-item"><li><span><a href="#Сколько-человек-в-каждом-классе-дохода?" data-toc-modified-id="Сколько-человек-в-каждом-классе-дохода?-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Сколько человек в каждом классе дохода?</a></span></li><li><span><a href="#Какой-класс-на-что-берёт-кредиты?" data-toc-modified-id="Какой-класс-на-что-берёт-кредиты?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Какой класс на что берёт кредиты?</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Исследование надёжности заёмщиков
# # Описание проекта
# **Заказчик** — кредитный отдел банка.
#
# **Входные данные от банка** — статистика о платёжеспособности клиентов.
#
# **Цель** — разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# **Дополнительный уровень:**
#
# Совершить оптимизацию данных для экономия памяти.
#
# # Описание данных
# * `children` — количество детей в семье
# * `days_employed` — общий трудовой стаж в днях
# * `dob_years` — возраст клиента в годах
# * `education` — уровень образования клиента
# * `education_id` — идентификатор уровня образования
# * `family_status` — семейное положение
# * `family_status_id` — идентификатор семейного положения
# * `gender` — пол клиента
# * `income_type` — тип занятости
# * `debt` — имел ли задолженность по возврату кредитов
# * `total_income` — ежемесячный доход
# * `purpose` — цель получения кредита

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# ### Оптимизация данных

# %%
# загрузим библиотеки
import pandas as pd
import numpy as np

# %%
# посмотрим на первые 5 строк
df = pd.read_csv('/datasets/data.csv')
df.head(5)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %%
# общая информация
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
# более подробные данные по используемой памяти
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 11.3 MB

# %%
'''Исследуем использование памяти разными типами данных. 
Начнём со среднего показателя использования памяти по разным типам данных.'''
for dtype in ['float','int','object']:
    selected_dtype = df.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype, mean_usage_mb))
# Out:
# Average memory usage for float columns: 0.11 MB
# Average memory usage for int columns: 0.00 MB
# Average memory usage for object columns: 1.69 MB

# %% [markdown]
# Эти сведения дают нам понять то, что большая часть памяти уходит на 5 столбцов, хранящих объектные значения.

# %%
'''Для проверки минимального и максимального значения, 
подходящего для хранения с использованием каждого целочисленного подтипа, 
можно воспользоваться методом numpy.iinfo(). Рассмотрим пример:'''
int_types = ["uint8", "int8", "int16"]
for it in int_types:
    print(np.iinfo(it))
# Out:
# Machine parameters for uint8
# ---------------------------------------------------------------
# min = 0
# max = 255
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------

# %% [markdown]
# Тут можно обратить внимание на различие между типами uint (беззнаковое целое) и int (целое число со знаком). Оба типа имеют одинаковую ёмкость, но, при хранении в столбцах только положительных значений, беззнаковые типы позволяют эффективнее расходовать память.

# %%
# создадим функцию, которая поможет нам сэкономить немного времени на выяснении сколько памяти используется.

def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: # исходим из предположения о том, что если это не DataFrame, то это Series
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # преобразуем байты в мегабайты
    return "{:03.2f} MB".format(usage_mb)

# %%
gl_int = df.select_dtypes(include=['int'])
converted_int = gl_int.apply(pd.to_numeric,downcast='unsigned')

print(mem_usage(gl_int))
print(mem_usage(converted_int))

compare_ints = pd.concat([gl_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns = ['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
# 0.00 MB
# 0.00 MB
# Empty DataFrame
# Columns: [before, after]
# Index: []

# %%
gl_float = df.select_dtypes(include=['float'])
converted_float = gl_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(gl_float))
print(mem_usage(converted_float))

compare_floats = pd.concat([gl_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns = ['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 0.33 MB
# 0.16 MB
#          before  after
# float32     NaN    2.0
# float64     2.0    NaN

# %%
optimized_gl = df.copy()

optimized_gl[converted_int.columns] = converted_int
optimized_gl[converted_float.columns] = converted_float

print(mem_usage(df))
print(mem_usage(optimized_gl))
# Out:
# 11.28 MB
# 11.12 MB

# %%
'''Для того чтобы понять, где именно мы сможем воспользоваться категориальными данными для снижения потребления памяти,
выясним количество уникальных значений в столбцах, хранящих значения объектных типов:'''
gl_obj = df.select_dtypes(include=['object']).copy()
gl_obj.describe()
# Out:
#        education    family_status gender income_type  purpose
# count      21525            21525  21525       21525    21525
# unique        15                5      3           8       38
# top      среднее  женат / замужем      F   сотрудник  свадьба
# freq       13750            12380  14236       11119      797

# %%
dow = gl_obj.family_status
print(dow.head())

dow_cat = dow.astype('category')
print(dow_cat.head())
# Out:
# 0     женат / замужем
# 1     женат / замужем
# 2     женат / замужем
# 3     женат / замужем
# 4    гражданский брак
# Name: family_status, dtype: object
# 0     женат / замужем
# 1     женат / замужем
# 2     женат / замужем
# 3     женат / замужем
# 4    гражданский брак
# Name: family_status, dtype: category
# Categories (5, object): ['Не женат / не замужем', 'в разводе', 'вдовец / вдова', 'гражданский брак', 'женат / замужем']

# %%
dow_cat.head().cat.codes
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    3
# dtype: int8

# %% [markdown]
# Тут можно заметить то, что каждому уникальному значению назначено целочисленное значение, и то, что столбец теперь имеет тип int8.

# %%
print(mem_usage(dow))
print(mem_usage(dow_cat))
# Out:
# 2.93 MB
# 0.02 MB

# %% [markdown]
# Потребление памяти до и после преобразования столбца family_status к типу category.

# %%
'''Создадим цикл, который перебирает все столбцы, хранящие данные типа object, 
выясняет не превышает ли число уникальных значений в столбцах 50% 
и если это так, преобразует их в тип category.'''
converted_obj = pd.DataFrame()

for col in gl_obj.columns:
    num_unique_values = len(gl_obj[col].unique())
    num_total_values = len(gl_obj[col])
    if num_unique_values / num_total_values < 0.5:
        converted_obj.loc[:,col] = gl_obj[col].astype('category')
    else:
        converted_obj.loc[:,col] = gl_obj[col]

# %% [markdown]
# Сравним то, что получилось после оптимизации, с тем, что было раньше:

# %%
print(mem_usage(gl_obj))
print(mem_usage(converted_obj))

compare_obj = pd.concat([gl_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns = ['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 12.34 MB
# 0.11 MB
#           before  after
# object       5.0    NaN
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0
# category     NaN    1.0

# %%
# проанализируем то, на какой уровень использования памяти мы вышли, если сравнить то, что получилось
optimized_gl[converted_obj.columns] = converted_obj

print(mem_usage(optimized_gl))
# Out:
# 1.10 MB

# %%
dtypes = optimized_gl.dtypes

dtypes_col = dtypes.index
dtypes_type = [i.name for i in dtypes.values]

column_types = dict(zip(dtypes_col, dtypes_type))

'''Возьмём пары ключ/значение из словаря
и аккуратно их выведем
'''
preview = first2pairs = {key:value for key,value in list(column_types.items())}
import pprint
pp = pp = pprint.PrettyPrinter(indent=4)
pp.pprint(preview)
# Out:
# {   'children': 'int64',
#     'days_employed': 'float32',
#     'debt': 'int64',
#     'dob_years': 'int64',
#     'education': 'category',
#     'education_id': 'int64',
#     'family_status': 'category',
#     'family_status_id': 'int64',
#     'gender': 'category',
#     'income_type': 'category',
#     'purpose': 'category',
#     'total_income': 'float32'}

# %%
read_and_optimized = pd.read_csv('/datasets/data.csv',dtype=column_types,infer_datetime_format=True)

print(mem_usage(read_and_optimized))
display(read_and_optimized.head())
u_memory = 1 - (1.10 / 11.3)
print(f'Экономия памяти: {u_memory:.2%}')
# Out:
# 1.10 MB
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.672852         42    высшее             0
# 1         1   -4024.803711         36   среднее             1
# 2         0   -5623.422852         33   Среднее             1
# 3         3   -4124.747070         32   среднее             1
# 4         0  340266.062500         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.640625
# 1   женат / замужем                 0      F   сотрудник     0  112080.015625
# 2   женат / замужем                 0      M   сотрудник     0  145885.953125
# 3   женат / замужем                 0      M   сотрудник     0  267628.562500
# 4  гражданский брак                 1      F   пенсионер     0  158616.078125
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %%
read_and_optimized.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float32
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  category
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  category
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  category
#  8   income_type       21525 non-null  category
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float32
#  11  purpose           21525 non-null  category
# dtypes: category(5), float32(2), int64(5)
# memory usage: 1.1 MB

# %% [markdown]
# **1. Поиск пропусков:**

# %%
read_and_optimized.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **2. Поиск аномалий:**

# %%
# посмотрим на данные(5 первых строк)
read_and_optimized[:5]
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.672852         42    высшее             0
# 1         1   -4024.803711         36   среднее             1
# 2         0   -5623.422852         33   Среднее             1
# 3         3   -4124.747070         32   среднее             1
# 4         0  340266.062500         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.640625
# 1   женат / замужем                 0      F   сотрудник     0  112080.015625
# 2   женат / замужем                 0      M   сотрудник     0  145885.953125
# 3   женат / замужем                 0      M   сотрудник     0  267628.562500
# 4  гражданский брак                 1      F   пенсионер     0  158616.078125
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %% [markdown]
# Замечено отрицательное количество дней трудового стажа в столбце `days_employed`.

# %% [markdown]
# **3. Поиск дубликатов:**

# %%
print(f'Число явных дубликатов: {read_and_optimized.duplicated().sum()}')
read_and_optimized[read_and_optimized.duplicated()][:5]
# Out:
# Число явных дубликатов: 54
#       children  days_employed  dob_years education  education_id  \
# 2849         0            NaN         41   среднее             1
# 4182         1            NaN         34    ВЫСШЕЕ             0
# 4851         0            NaN         60   среднее             1
# 5557         0            NaN         58   среднее             1
# 7808         0            NaN         57   среднее             1
#
#          family_status  family_status_id gender income_type  debt  \
# 2849   женат / замужем                 0      F   сотрудник     0
# 4182  гражданский брак                 1      F   сотрудник     0
# 4851  гражданский брак                 1      F   пенсионер     0
# 5557  гражданский брак                 1      F   пенсионер     0
# 7808  гражданский брак                 1      F   пенсионер     0
#
#       total_income                  purpose
# 2849           NaN  покупка жилья для семьи
# 4182           NaN                  свадьба
# ...

# %% [markdown]
# **В столбце `education` есть одни и те же значения(неявные дубликаты), но записанные по-разному: с использованием заглавных и строчных букв.**

# %% [markdown]
# ### Вывод

# %% [markdown]
# Выполнен **дополнительный уровень** для экономия памяти. Экономия памяти составила: 90.27%.
#
# **Найдены проблемы в данных:**
# 1. В двух столбцах есть пропущенные значения. Один из них — `days_employed`, второй - `total_income`.
# 2. Замечена аномалия в данных, отрицательное количество дней трудового стажа в столбце `days_employed`. Так же есть  аномальное значение "-1" в  столбце `children`.
# 3. Столбец `education` содержит неявные дубликаты, значения повторяются, но записаны в разных регистрах. Так же в данных присутствует 54 явных дубликата.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропуски в столбцах days_employed и total_income

# %%
print(f'''Пропусков в столбце `days_employed` - {read_and_optimized.days_employed.isna().sum()}
Это {round(read_and_optimized.days_employed.isna().sum() / len(read_and_optimized) * 100, 2)}% от общего числа данных.''')
# Out:
# Пропусков в столбце `days_employed` - 2174
# Это 10.1% от общего числа данных.

# %%
print(f'''Пропусков в столбце `total_income` до изменений - {read_and_optimized.total_income.isna().sum()}
Это {round(read_and_optimized.total_income.isna().sum() / len(read_and_optimized) * 100, 2)}% от общего числа данных.
Возможная причина появления пропусков в данных - человеческий фактор. 
Пропуски по обоим столбцам находятся в одинаковых строках.
Выглядят эти пропуски так:''')
read_and_optimized[read_and_optimized.total_income.isna()][:5]
# Out:
# Пропусков в столбце `total_income` до изменений - 2174
# Это 10.1% от общего числа данных.
# Возможная причина появления пропусков в данных - человеческий фактор.
# Пропуски по обоим столбцам находятся в одинаковых строках.
# Выглядят эти пропуски так:
#     children  days_employed  dob_years education  education_id  \
# 12         0            NaN         65   среднее             1
# 26         0            NaN         41   среднее             1
# 29         0            NaN         63   среднее             1
# 41         0            NaN         50   среднее             1
# 55         0            NaN         54   среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 12       гражданский брак                 1      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
# ...

# %%
print(f'''Строк до изменений: {read_and_optimized.shape[0]}
Столбцов до изменений: {read_and_optimized.shape[1]}''')
# заполним пропущенные значения в total_income медианным значением
read_and_optimized.total_income = read_and_optimized.total_income.fillna(read_and_optimized.total_income.median())
# Out:
# Строк до изменений: 21525
# Столбцов до изменений: 12

# %%
print(f'''Строк после изменений: {read_and_optimized.shape[0]}
Столбцов после изменений: {read_and_optimized.shape[1]}
Пропусков в столбце `total_income` после замены - {read_and_optimized.total_income.isna().sum()}
Выглядит это так:''')
read_and_optimized[read_and_optimized.days_employed.isna()][:5]
# Out:
# Строк после изменений: 21525
# Столбцов после изменений: 12
# Пропусков в столбце `total_income` после замены - 0
# Выглядит это так:
#     children  days_employed  dob_years education  education_id  \
# 12         0            NaN         65   среднее             1
# 26         0            NaN         41   среднее             1
# 29         0            NaN         63   среднее             1
# 41         0            NaN         50   среднее             1
# 55         0            NaN         54   среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 12       гражданский брак                 1      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
# 41        женат / замужем                 0      F  госслужащий     0
# 55       гражданский брак                 1      F    пенсионер     1
#
# ...

# %% [markdown]
# **Вывод:**
#
# Заполнить пропуски медианным значением — лучшее решение для количественных переменных, потому что в таком случае можно перекрыть выбросы по значениям(как минимальным, так и максимальным) без весомых последствий для картины в целом.

# %% [markdown]
# ### Аномалии в данных

# %%
# до изменений
display(read_and_optimized[:5])
# исправим отрицательное количество дней трудового стажа в столбце days_employed и children
read_and_optimized.days_employed = abs(read_and_optimized.days_employed)
read_and_optimized.children = abs(read_and_optimized.children)
# заполним пропуски в days_employed медианным значением
read_and_optimized.days_employed = read_and_optimized.days_employed.fillna(read_and_optimized.days_employed.median())
# аномалия в данных по детям
read_and_optimized.children = read_and_optimized.children.replace(20, 2)
# неправильно указанный пол, исключим эту строку
read_and_optimized = read_and_optimized[read_and_optimized.gender != 'XNA']
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.672852         42    высшее             0
# 1         1   -4024.803711         36   среднее             1
# 2         0   -5623.422852         33   Среднее             1
# 3         3   -4124.747070         32   среднее             1
# 4         0  340266.062500         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.640625
# 1   женат / замужем                 0      F   сотрудник     0  112080.015625
# 2   женат / замужем                 0      M   сотрудник     0  145885.953125
# 3   женат / замужем                 0      M   сотрудник     0  267628.562500
# 4  гражданский брак                 1      F   пенсионер     0  158616.078125
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %%
# после изменений
read_and_optimized[:5]
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.672852         42    высшее             0
# 1         1    4024.803711         36   среднее             1
# 2         0    5623.422852         33   Среднее             1
# 3         3    4124.747070         32   среднее             1
# 4         0  340266.062500         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.640625
# 1   женат / замужем                 0      F   сотрудник     0  112080.015625
# 2   женат / замужем                 0      M   сотрудник     0  145885.953125
# 3   женат / замужем                 0      M   сотрудник     0  267628.562500
# 4  гражданский брак                 1      F   пенсионер     0  158616.078125
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %% [markdown]
# **Вывод:**
#
# В столбцах `days_employed` и `children` исправлена аномалия с "-", заполнены пропуски в `days_employed`, скорректирована аномалия в значениях столбца `children` и `gender`.

# %% [markdown]
# ### Замена типа данных в столбце total_income

# %%
# до изменений
read_and_optimized.info()
# замена типа данных на int
read_and_optimized.total_income = read_and_optimized.total_income.astype('int64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21524 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21524 non-null  int64
#  1   days_employed     21524 non-null  float32
#  2   dob_years         21524 non-null  int64
#  3   education         21524 non-null  category
#  4   education_id      21524 non-null  int64
#  5   family_status     21524 non-null  category
#  6   family_status_id  21524 non-null  int64
#  7   gender            21524 non-null  category
#  8   income_type       21524 non-null  category
#  9   debt              21524 non-null  int64
#  10  total_income      21524 non-null  float32
#  11  purpose           21524 non-null  category
# dtypes: category(5), float32(2), int64(5)
# memory usage: 1.3 MB

# %%
# после изменений
read_and_optimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21524 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21524 non-null  int64
#  1   days_employed     21524 non-null  float32
#  2   dob_years         21524 non-null  int64
#  3   education         21524 non-null  category
#  4   education_id      21524 non-null  int64
#  5   family_status     21524 non-null  category
#  6   family_status_id  21524 non-null  int64
#  7   gender            21524 non-null  category
#  8   income_type       21524 non-null  category
#  9   debt              21524 non-null  int64
#  10  total_income      21524 non-null  int64
#  11  purpose           21524 non-null  category
# dtypes: category(5), float32(1), int64(6)
# memory usage: 1.3 MB

# %% [markdown]
# **Вывод:**
#
# Вещественный тип данных был заменён на целочисленный в столбце `total_income`.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# **Явные дубликаты**

# %%
# до изменений
display(read_and_optimized.shape)
# удаление явных дубликатов
read_and_optimized = read_and_optimized.drop_duplicates().reset_index(drop=True)
# после изменений
display(read_and_optimized.shape)
# Out:
# (21524, 12)
# (21470, 12)

# %% [markdown]
# **Неявные дубликаты**

# %%
# до изменений в education
list(read_and_optimized.education.unique())
# Out:
# ['высшее',
#  'среднее',
#  'Среднее',
#  'СРЕДНЕЕ',
#  'ВЫСШЕЕ',
#  'неоконченное высшее',
#  'начальное',
#  'Высшее',
#  'НЕОКОНЧЕННОЕ ВЫСШЕЕ',
#  'Неоконченное высшее',
#  'НАЧАЛЬНОЕ',
#  'Начальное',
#  'Ученая степень',
#  'УЧЕНАЯ СТЕПЕНЬ',
#  'ученая степень']

# %%
# приведение к нижнему регистру education
read_and_optimized.education = read_and_optimized.education.str.lower().astype('category')
# после изменений в education
list(read_and_optimized.education.unique())
# Out:
# ['высшее', 'среднее', 'неоконченное высшее', 'начальное', 'ученая степень']

# %%
# по итогу данные  выглядят так
read_and_optimized[5:]
# Out:
#        children  days_employed  dob_years education  education_id  \
# 5             0     926.185852         27    высшее             0
# 6             0    2879.202148         43    высшее             0
# 7             0     152.779572         50   среднее             1
# 8             2    6929.865234         35    высшее             0
# 9             0    2188.756348         41   среднее             1
# ...         ...            ...        ...       ...           ...
# 21465         1    4529.316895         43   среднее             1
# 21466         0  343937.406250         67   среднее             1
# 21467         1    2113.346924         38   среднее             1
# 21468         3    3112.481689         38   среднее             1
# 21469         2    1984.507568         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 5      гражданский брак                 1      M   компаньон     0
# ...

# %% [markdown]
# Поиск дубликатов произодился в двух направлениях, по явным и неявным дубликатам. В этом помогли: метод `.duplicated().sum()` по явным дубликатам и метод `.unique()` для поиска неявных дубликатов.
#
# Возможные причины появления дубликатов: человеческий фактор(неявные дубликаты) и технологический фактор(явные дубликаты).

# %%
read_and_optimized.education.unique()
# Out:
# ['высшее', 'среднее', 'неоконченное высшее', 'начальное', 'ученая степень']
# Categories (5, object): ['высшее', 'среднее', 'неоконченное высшее', 'начальное', 'ученая степень']

# %%
read_and_optimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21470 entries, 0 to 21469
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21470 non-null  int64
#  1   days_employed     21470 non-null  float32
#  2   dob_years         21470 non-null  int64
#  3   education         21470 non-null  category
#  4   education_id      21470 non-null  int64
#  5   family_status     21470 non-null  category
#  6   family_status_id  21470 non-null  int64
#  7   gender            21470 non-null  category
#  8   income_type       21470 non-null  category
#  9   debt              21470 non-null  int64
#  10  total_income      21470 non-null  int64
#  11  purpose           21470 non-null  category
# dtypes: category(5), float32(1), int64(6)
# memory usage: 1.2 MB

# %% [markdown]
# **Вывод:**
#
# Была произведена чистка данных, выявлены и устранены явные и неявные дубликаты, проработана индексация.

# %% [markdown]
# ### Создание двух новых датафреймов

# %% [markdown]
# **1. Первый датафрейм:**

# %%
# каждому уникальному значению из education соответствует уникальное значение education_id
edu_dict = read_and_optimized[['education','education_id']]
edu_dict = edu_dict.drop_duplicates(keep='first').reset_index(drop=True).sort_values(by='education_id', ascending=True)
edu_dict
# Out:
#              education  education_id
# 0               высшее             0
# 1              среднее             1
# 2  неоконченное высшее             2
# 3            начальное             3
# 4       ученая степень             4

# %% [markdown]
# **2. Второй датафрейм:**

# %%
# каждому уникальному значению из family_status соответствует уникальное значение family_status_id — во втором.
fam_dict = read_and_optimized[['family_status','family_status_id']]
fam_dict = fam_dict.drop_duplicates(keep='first').reset_index(drop=True).sort_values(by='family_status_id', ascending=True)
fam_dict
# Out:
#            family_status  family_status_id
# 0        женат / замужем                 0
# 1       гражданский брак                 1
# 2         вдовец / вдова                 2
# 3              в разводе                 3
# 4  Не женат / не замужем                 4

# %% [markdown]
# **3. Работа над исходником:**

# %%
# удалим из исходного датафрейма столбцы education и family_status, оставив только их идентификаторы: 
del read_and_optimized['education']
del read_and_optimized['family_status']

read_and_optimized.sample(5)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 2681          0  389359.468750         66             1                 2
# 9888          0  401123.562500         61             1                 0
# 16500         0    4389.959473         49             1                 1
# 7880          2     715.013855         35             1                 1
# 2076          1    3735.440918         43             1                 0
#
#       gender income_type  debt  total_income  \
# 2681       F   пенсионер     0         69823
# 9888       F   пенсионер     0        110723
# 16500      F   сотрудник     0        145121
# 7880       F   сотрудник     0        119869
# 2076       F   сотрудник     0        141910
#
#                                       purpose
# 2681                            покупка жилья
# 9888   строительство собственной недвижимости
# 16500                операции с недвижимостью
# 7880             на покупку своего автомобиля
# ...

# %% [markdown]
# ### Функция категории дохода

# %%
def total_income_category(total_income):
    """
    Функция возвращает категорию дохода(E,D,C,B,A) по значению total_income, используя правила:
    - 0–30000 — 'E';
    - 30001–50000 — 'D';
    - 50001–200000 — 'C';
    - 200001–1000000 — 'B';
    - 1000001 и выше — 'A'.
    Если что-то пошло не по плану вернёт 'Ошибка'
    """
    if 30000 >= total_income:
        return 'E'
    elif 30000 < total_income <= 50000:
        return 'D'
    elif 50000 < total_income <= 200000:
        return 'C'
    elif 200000 < total_income <= 1000000:
        return 'B'
    elif 1000000 < total_income:
        return 'A'
    else:
        return 'Ошибка'

# %%
# создадим новый столбец и применим функцию выше
read_and_optimized['total_income_category'] = read_and_optimized['total_income'].apply(total_income_category)

# %%
# результат
read_and_optimized.sample(5)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 1672          1    1190.566772         54             1                 1
# 8443          2    2194.220459         36             1                 0
# 2483          0    4105.045898         50             1                 0
# 13529         2     525.105713         40             1                 0
# 2037          0    9838.119141         47             0                 0
#
#       gender income_type  debt  total_income  \
# 1672       F   сотрудник     0        106436
# 8443       F   сотрудник     0        145017
# 2483       M   компаньон     0         94029
# 13529      F   компаньон     0        108171
# 2037       F   сотрудник     0        145149
#
#                                  purpose total_income_category
# 1672                          автомобили                     C
# 8443   покупка коммерческой недвижимости                     C
# ...

# %% [markdown]
# **Вывод:**
#
# Была создана функция для социально-экономической сегрегации клиектов банка. А именно: были выделенны классы по кол-ву доходов и назначены им условные обозначения(E,D,C,B,A). Эти обозначения принял на себя новый столбец - `total_income_category`.

# %% [markdown]
# ### Функция категоризации целей кредита

# %%
def purpose_category(purpose):
    '''
    Функция, которая на основании данных из столбца purpose сформирует новый столбец purpose_category,
    в который войдут следующие категории:
    - 'операции с автомобилем',
    - 'операции с недвижимостью',
    - 'проведение свадьбы',
    - 'получение образования'.
    '''
    if 'автомобил' in purpose:
        return 'операции с автомобилем'
    elif 'недвижимост' in purpose:
        return 'операции с недвижимостью'
    elif 'жиль' in purpose:
        return 'операции с недвижимостью'
    elif 'свадьб' in purpose:
        return 'проведение свадьбы'
    elif 'образован' in purpose:
        return 'получение образования'
    else:
        return 'уникальный случай'

# %%
# применим функцию
read_and_optimized['purpose_category'] = read_and_optimized['purpose'].apply(purpose_category)
# результат
read_and_optimized.sample(5)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 17228         2    2026.475098         34             1                 0
# 18002         0  371295.031250         65             1                 2
# 13183         0    3191.038086         48             1                 0
# 20088         0    2954.331055         47             1                 0
# 15909         1    2444.441895         34             1                 0
#
#       gender income_type  debt  total_income  \
# 17228      F   компаньон     0        174247
# 18002      F   пенсионер     0        117550
# 13183      M   сотрудник     0        221212
# 20088      M   сотрудник     0         83552
# 15909      M   сотрудник     0        106925
#
#                                      purpose total_income_category  \
# 17228           на покупку своего автомобиля                     C
# 18002       строительство жилой недвижимости                     C
# ...

# %% [markdown]
# **Вывод:**
#
# Создали функцию, чтобы избавить от неявных дубликатов в столбце `purpose`.

# %% [markdown]
# ## Ответы на вопросы

# %% [markdown]
# ### Зависимость между количеством детей и возвратом кредита в срок?

# %%
child_debt = read_and_optimized.pivot_table(index=['children'], values='debt', aggfunc='mean').reset_index()
child_debt['debt'] =  round(child_debt['debt'], 4) * 100
child_debt
# Out:
#    children  debt
# 0         0  7.54
# 1         1  9.16
# 2         2  9.49
# 3         3  8.18
# 4         4  9.76
# 5         5  0.00

# %% [markdown]
# **Вывод:**
#
# Дети увеличивают нагрузку и повышают риски по невозрату кредита. Для принятия решения по выдачи кредита рекомендуется смотреть на дополнительные параметры по клиенту.

# %% [markdown]
# ### Зависимость между семейным положением и возвратом кредита в срок?

# %%
fam_debt = fam_dict.merge(read_and_optimized)
fam_debt = fam_debt[['family_status', 'family_status_id', 'debt']]
fam_debt = fam_debt.pivot_table(index=['family_status'], values='debt', aggfunc='mean').reset_index()
fam_debt['debt'] =  round(fam_debt['debt'], 4) * 100
fam_debt
# Out:
#            family_status  debt
# 0  Не женат / не замужем  9.75
# 1              в разводе  7.11
# 2         вдовец / вдова  6.57
# 3       гражданский брак  9.32
# 4        женат / замужем  7.54

# %% [markdown]
# **Вывод:**
#
# Рискованными являются займы клиентам с семейным положением: "Не женат / не замужем", "гражданский брак".

# %% [markdown]
# ### Зависимость между уровнем дохода и возвратом кредита в срок?

# %%
income_category_debt = read_and_optimized.pivot_table(index=['total_income_category'], values='debt', aggfunc='mean').reset_index()
income_category_debt['debt'] =  round(income_category_debt['debt'], 4) * 100
income_category_debt
#Напоминание по категориям:
#    - 0–30000 — 'E'
#    - 30001–50000 — 'D'
#    - 50001–200000 — 'C'
#    - 200001–1000000 — 'B'
#    - 1000001 и выше — 'A'
# Out:
#   total_income_category  debt
# 0                     A  8.00
# 1                     B  7.06
# 2                     C  8.48
# 3                     D  6.00
# 4                     E  9.09

# %% [markdown]
# **Вывод:**
#
# Люди с доходом в категории "Е" - самые рисковые, в категории "D" - самые нерисковые.

# %% [markdown]
# ### Как разные цели кредита влияют на его возврат в срок?

# %%
purpose_category_debt = read_and_optimized.pivot_table(index=['purpose_category'], values='debt', aggfunc='mean').reset_index()
purpose_category_debt['debt'] =  round(purpose_category_debt['debt'], 4) * 100
purpose_category_debt
# Out:
#            purpose_category  debt
# 0    операции с автомобилем  9.35
# 1  операции с недвижимостью  7.23
# 2     получение образования  9.22
# 3        проведение свадьбы  7.97

# %% [markdown]
# **Вывод:**
#
# Как видно из данных жив социальный институт семьи, т.е. кредиты на проведение свадьбы - не рисковые. К этому можно добавить операции с недвижимостью.

# %% [markdown]
# ## Дополнительные вопросы и ответы на них

# %% [markdown]
# ### Сколько человек в каждом классе дохода?

# %%
social_classes = read_and_optimized.pivot_table(index=['total_income_category'], values='debt', aggfunc='count').reset_index()
#social_classes['debt'] = round(social_classes['debt'], 4) * 100
display(social_classes)
print(f'''Вывод:
Выборка переполнена классами B({social_classes['debt'][1]}) и C({social_classes['debt'][2]}).''')
# Out:
#   total_income_category   debt
# 0                     A     25
# 1                     B   5040
# 2                     C  16033
# 3                     D    350
# 4                     E     22
# Вывод:
# Выборка переполнена классами B(5040) и C(16033).

# %% [markdown]
# Число доходов в этих группах:
#  - 50001–200000 — 'C'
#  - 200001–1000000 — 'B'
#
# Банк задействовал их по максимуму.

# %% [markdown]
# ###  Какой класс на что берёт кредиты?

# %%
social_classes_p = read_and_optimized.pivot_table(index=['total_income_category', 'purpose_category'], values='debt', aggfunc=['count', 'mean']).reset_index()
social_classes_p['mean', 'debt'] = round(social_classes_p['mean']['debt'], 4) * 100
display(social_classes_p)
# Out:
#    total_income_category          purpose_category count   mean
#                                                     debt   debt
# 0                      A    операции с автомобилем     2   0.00
# 1                      A  операции с недвижимостью    17   5.88
# 2                      A     получение образования     4  25.00
# 3                      A        проведение свадьбы     2   0.00
# 4                      B    операции с автомобилем  1031   8.34
# 5                      B  операции с недвижимостью  2567   6.70
# 6                      B     получение образования   897   7.80
# 7                      B        проведение свадьбы   545   5.14
# 8                      C    операции с автомобилем  3201   9.59
# 9                      C  операции с недвижимостью  8050   7.47
# 10                     C     получение образования  3032   9.80
# 11                     C        проведение свадьбы  1750   8.86
# 12                     D    операции с автомобилем    72  13.89
# ...

# %% [markdown]
# **Вывод:**
#
# По данной сводной таблице можно увидеть предпочтения у классов и % просрочек по ним.
#
# Хотел бы обратить внимание на проблемы по каждому классу с возвратом денежных средств, это:
#  * E - операции с недвижимостью 18.18%;
#  * D - операции с автомобилем 13.89%;
#  * C - получение образования 9.8%;
#  * B - операции с автомобилем 8.34%;
#  * A - получение образования - 25.0%.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# **В кратце:**
#
# Во-первых, была произведена оптимизация данных для экономия памяти. Во-вторых, выполнена предобработка данных. В-третьих, даны ответы на интересующие вопросы.
#
# **Данные для построения модели кредитного скоринга:**
#
# На чём можно заработать?
#
# Цель кредита - "операции с недвижимостью" или "проведение свадьбы"
# * Портрет клиента:
#  * Категория дохода - A, B, C, D
#  * Семейный статус - "в разводе", "вдовец / вдова", "женат / замужем"
#  * Число детей - 0
#
# Нужно помнить, что человек живёт согласно своих средств и того, что он может вернуть. Чем больше его доход, тем больше возможности.
